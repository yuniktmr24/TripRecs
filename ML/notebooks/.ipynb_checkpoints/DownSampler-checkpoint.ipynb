# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /Users/yuniktamrakar/.pyenv/versions/3.10.3/lib/python3.10/site-packages (10.0.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Single image resize

# %%
from PIL import Image
def resize_image_by_percentage(input_path, output_path, percentage):
    with Image.open(input_path) as img:
        width, height = img.size
        new_dimensions = (int(width * percentage / 100), int(height * percentage / 100))
        resized_img = img.resize(new_dimensions, Image.Resampling.LANCZOS)
        resized_img.save(output_path)

# Example usage:
input_path = '../1532e8521f3f99b23277dcab086ca9ee.jpg'
output_path = '../resize.jpg'
percentage = 50  # Resize to 50% of the original size
resize_image_by_percentage(input_path, output_path, percentage)

# %% [markdown]
# ### All images in a directory resize

# %%
from PIL import Image
import os

def resize_image_by_percentage(input_path, output_path, percentage):
    """Resize image by a percentage and save to output path."""
    with Image.open(input_path) as img:
        width, height = img.size
        new_dimensions = (int(width * percentage / 100), int(height * percentage / 100))
        resized_img = img.resize(new_dimensions, Image.Resampling.LANCZOS)
        resized_img.save(output_path)

def resize_images_in_directory(source_dir, target_dir, percentage):
    """Resize all images in the source directory and save them to the target directory."""
    # Create the target directory if it does not exist
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    
    for filename in os.listdir(source_dir):
        # Construct the full file path
        input_path = os.path.join(source_dir, filename)
        output_path = os.path.join(target_dir, filename)
        
        # Check if the file is an image (you might want to add other formats)
        if input_path.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
            resize_image_by_percentage(input_path, output_path, percentage)
            print(f"Resized and saved: {output_path}")
        else:
            print(f"Skipped non-image file: {filename}")

# Example usage:
folder_name = '50.Noratus_Cemetery_Armenia'
source_directory = '../landmark_images/train/' + folder_name
target_directory = '../resize/' + folder_name
percentage = 25  # Resize to 50% of the original size

resize_images_in_directory(source_directory, target_directory, percentage)
# Out:
# Resized and saved: ../resize/folder_name/f1a69dff26bedecfb8b771882350bfb0.jpg
# Resized and saved: ../resize/folder_name/18f1f6a4d186d50151d5c43f55c0beb2.jpg
# Resized and saved: ../resize/folder_name/736581cb08fc9783983ae155271800aa.jpg
# Resized and saved: ../resize/folder_name/a5302cacb29da23cd28a078aaf884cbe.jpg
# Resized and saved: ../resize/folder_name/e6e390e38a2d5bcc36cd963b4449a144.jpg
# Resized and saved: ../resize/folder_name/41739f739bca05a443d26d6adb3d084a.jpg
# Resized and saved: ../resize/folder_name/d1bea427ac72da9c95b3d29b7c0fdb15.jpg
# Resized and saved: ../resize/folder_name/54294803bc5f73854b86c81e782c42ba.jpg
# Resized and saved: ../resize/folder_name/1ed0ecb769214df38e57a5a8fbc2dcbd.jpg
# Resized and saved: ../resize/folder_name/10fd3332cb2869638cdf5e9a1fb15b11.jpg
# Resized and saved: ../resize/folder_name/c55cbffc1826ef833a3e2755c2cc39da.jpg
# Resized and saved: ../resize/folder_name/7313144326f70d46e759d6522cc47f68.jpg
# Resized and saved: ../resize/folder_name/25f3e4d9309e3cd7716c73573814cbc3.jpg
# Resized and saved: ../resize/folder_name/4d64f725c70d8cd5fcd3088999294f3e.jpg
# Resized and saved: ../resize/folder_name/d550578ca7d2bf6ead4ae1b6850346962.jpg
# Resized and saved: ../resize/folder_name/25328a90de45bab91ed7ae07ea1f53fe.jpg
# Resized and saved: ../resize/folder_name/2bc4ff13ac352dc55bd990ebeb5335c7.jpg
# Resized and saved: ../resize/folder_name/8d69d9ed99d5d93e2e6582eb29cf076b.jpg
# Resized and saved: ../resize/folder_name/dd185ad44b01c3d5ce45a55ae671b3f42.jpg
# Resized and saved: ../resize/folder_name/6ad0b87900654a3ac95750e4e1ddf3a3.jpg
# Resized and saved: ../resize/folder_name/37c4c9459c2cbd1a8fb62d9aaedac6db.jpg
# Resized and saved: ../resize/folder_name/8161599d2fcad7f96735f2e003f4c82c.jpg
# Resized and saved: ../resize/folder_name/89da545ec25f7195b4881786851ff4b5.jpg
# Resized and saved: ../resize/folder_name/519d685ae11c6fbe6463bc79ae80e3f3.jpg
# Resized and saved: ../resize/folder_name/5351cc0ff935fd29ca77384d241765d8.jpg
# Resized and saved: ../resize/folder_name/10f375d35a93008b50250881ce932142.jpg
# Resized and saved: ../resize/folder_name/6776199c2c184ffd82d233dbee089e4a.jpg
# Resized and saved: ../resize/folder_name/dd185ad44b01c3d5ce45a55ae671b3f4.jpg
# Resized and saved: ../resize/folder_name/44b8e52264ec0b6b6b2c642849dde8b3.jpg
# Resized and saved: ../resize/folder_name/24c4a4720eab5896f840afa352d2a7d2.jpg
# Resized and saved: ../resize/folder_name/bbd10e5a88a392737d5e37fa2121708d.jpg
# Resized and saved: ../resize/folder_name/2142229cb1d252fd3e29dd530bfd4b6c.jpg
# Resized and saved: ../resize/folder_name/e7a01b0eff38708d8fca5ac29c4f110a2.jpg
# Resized and saved: ../resize/folder_name/77a99afe55b37f17b07cdd8c1981a7f1.jpg
# Resized and saved: ../resize/folder_name/9cfad0b335d0cf5ab4dcc2bb76469980.jpg
# Resized and saved: ../resize/folder_name/6064240a0b1d173853f855952b7e4612.jpg
# Resized and saved: ../resize/folder_name/fa2f32b82782739c71b09eb636f9424e.jpg
# Resized and saved: ../resize/folder_name/78006f776e801122e7ff2e260278b8db.jpg
# Resized and saved: ../resize/folder_name/be6dd4d3659aba7a2512046e24c07b61.jpg
# Resized and saved: ../resize/folder_name/bb726fb34ddf32d1522835abdcad18de.jpg
# Resized and saved: ../resize/folder_name/136695b711e75895a8210969044052c9.jpg
# Resized and saved: ../resize/folder_name/c10deb61cd0cb78214d0e6f7e1b9ceb93.jpg
# Resized and saved: ../resize/folder_name/b0dd7983d1407e39e50396de98560e69.jpg
# Resized and saved: ../resize/folder_name/5cbb2d328c649e814dbb2a5c10cefd14.jpg
# Resized and saved: ../resize/folder_name/163ef981522a3e82b3493651f1a2c7ee.jpg
# Resized and saved: ../resize/folder_name/833e652b2701f403c1d2fdb20e08c222.jpg
# Resized and saved: ../resize/folder_name/f62f941a05a1a370b67d22478b92adf5.jpg
# Resized and saved: ../resize/folder_name/181b1eb6dc17504bd95f3f05dafb3b8c.jpg
# Resized and saved: ../resize/folder_name/72ad9339af1d8bf258588b46762d6148.jpg
# Resized and saved: ../resize/folder_name/84411ca7e72a1fb9216a4e84e07112a9.jpg
# Resized and saved: ../resize/folder_name/d550578ca7d2bf6ead4ae1b685034696.jpg
# Resized and saved: ../resize/folder_name/41f78fc849624309dd73dce0bac212a2.jpg
# Resized and saved: ../resize/folder_name/c10deb61cd0cb78214d0e6f7e1b9ceb9.jpg
# Resized and saved: ../resize/folder_name/4de50b79a3ea197bca12717f1c26a36f.jpg
# Resized and saved: ../resize/folder_name/2fb992e686a92f58034fccfbe24a3cbe.jpg
# Resized and saved: ../resize/folder_name/03688c16f84dd9b4c7f392b0185bb855.jpg
# Resized and saved: ../resize/folder_name/b08657eca25f67b01fb3c619f133672e.jpg
# Resized and saved: ../resize/folder_name/8a21d27d390eab3853461ae7410f81c5.jpg
# Resized and saved: ../resize/folder_name/ed9e10c792dabeab7c74d82e4eb282be.jpg
# Resized and saved: ../resize/folder_name/71c050f14d3c58e42cabfa5c8cee43c6.jpg
# Resized and saved: ../resize/folder_name/ff1452886441edcdd1eeabcd67ca8714.jpg
# Resized and saved: ../resize/folder_name/e7a01b0eff38708d8fca5ac29c4f110a.jpg
# Resized and saved: ../resize/folder_name/001a03cad9ab03e3fb7c0c27fae87516.jpg
# Resized and saved: ../resize/folder_name/816661185d2461937ddd99fcaf1ff27c.jpg
# Resized and saved: ../resize/folder_name/759f197258d7e3418f814f1367be210d.jpg
# Resized and saved: ../resize/folder_name/c55ca1b4cd919a0f26f316a8f94fec4d.jpg
# Resized and saved: ../resize/folder_name/97a59597ecd30f63805ccd66b76c1169.jpg
# Resized and saved: ../resize/folder_name/271aa2633b029e6532af2692917cfa3d.jpg
# Resized and saved: ../resize/folder_name/b08657eca25f67b01fb3c619f133672e6.jpg
# Resized and saved: ../resize/folder_name/fdabe83b5933682fb723a0f009377d67.jpg
# Resized and saved: ../resize/folder_name/0e885c3fc4439910d830f176a0bb72a8.jpg
# Resized and saved: ../resize/folder_name/49787063312c6b253f7ffb40a6a8081a.jpg
# Resized and saved: ../resize/folder_name/4511f457710f35679f539fb0553b3505.jpg
# Resized and saved: ../resize/folder_name/82f2355a7357a90a3cbadf38b008be1c.jpg
# Resized and saved: ../resize/folder_name/9fff714357de21ae2afdf902aad14fca.jpg
# Resized and saved: ../resize/folder_name/c55cbffc1826ef833a3e2755c2cc39da1.jpg
# Resized and saved: ../resize/folder_name/843add991e32b99575711366c4bb594c.jpg
# Resized and saved: ../resize/folder_name/26f7c4cb8b3f3447b8c186c1f35295b5.jpg
# Resized and saved: ../resize/folder_name/a1161b23642ab56e90a32451922a2545.jpg
# Resized and saved: ../resize/folder_name/f61f942fc96fd598a132e03fbca93026.jpg
# Resized and saved: ../resize/folder_name/8f3b449aa43401712ed5a0a00936aaf1.jpg
# Resized and saved: ../resize/folder_name/cffb5f06a50bed71284dbc0d219c6fcc.jpg
# Resized and saved: ../resize/folder_name/31823a403cbf94c63720ec3ae85a1966.jpg
# Resized and saved: ../resize/folder_name/83ea686321c7b8ec988b755d570d6b12.jpg
# Resized and saved: ../resize/folder_name/184c84d8d4a51521cf9cd95c67d9da43.jpg
# Resized and saved: ../resize/folder_name/acd062e2230f90a56404a7edcde27993.jpg
# Resized and saved: ../resize/folder_name/3d90473264d50774433a9c84b35e30ba.jpg
# Resized and saved: ../resize/folder_name/20c2e302c12e1090b9c0d87bea9a22ff.jpg
# Resized and saved: ../resize/folder_name/385cff8a41f248c44bc10df35bf7d898.jpg
# Resized and saved: ../resize/folder_name/ce0dc1a548dd0f10f0475ceab27c826f.jpg
# Resized and saved: ../resize/folder_name/449319d530e68ff020b19e0c81c23038.jpg
# Resized and saved: ../resize/folder_name/90fadac0ab2b0787332c2ebebd0cebfd.jpg
# Resized and saved: ../resize/folder_name/82e20bf54504a01d231aa0cafa6349e7.jpg
# Resized and saved: ../resize/folder_name/d1bea427ac72da9c95b3d29b7c0fdb157.jpg
# Resized and saved: ../resize/folder_name/f62f941a05a1a370b67d22478b92adf53.jpg
# Resized and saved: ../resize/folder_name/2f14fa35ae59cb8c5b65ae0e25a7eb26.jpg
# Resized and saved: ../resize/folder_name/5b068de663eac4f998e54008c055f8ff.jpg
# Resized and saved: ../resize/folder_name/ce0dc1a548dd0f10f0475ceab27c826f2.jpg
# Resized and saved: ../resize/folder_name/941460fcdc007c30ef569db52cf5b380.jpg
# Resized and saved: ../resize/folder_name/ac95650f205e90e047c31c9b6126c125.jpg
